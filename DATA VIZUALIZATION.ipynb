# %% [markdown]
# # Title : ANALYSIS ON NEW BIKES
# ## Sub Title : Data Visualization of Bikes Data

# %% [markdown]
# ### Importing required libraries for data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the file

# %%
df=pd.read_csv(r"C:\\Users\\Manisha Reddy\\DATA SCIENCE\\WEB SCRAPING\\Web Scraping PROJECT\\cleaneddata.csv")

# %%
df
# Out:
#       Brand                         Model  Bike CC  Weight  Mileage  \
# 0     Royal       Royal Enfield Himalayan    411.0     191    45.00
# 1     Royal  Royal Enfield Classic Chrome    499.0     194    27.00
# 2     Royal      Royal Enfield Meteor 350    349.0     183    41.88
# 3     Royal      Royal Enfield Bullet 350    346.0     183    45.00
# 4      Hero               Hero Splendor +     97.2     110    70.00
# ..      ...                           ...      ...     ...      ...
# 356  BGauss                     BGauss A2    600.0      88   110.00
# 357      MV        MV Agusta Brutale 1090   1078.0     183    15.00
# 358  Indian        Indian Chieftain Elite   1811.0     388    18.00
# 359    EeVe                     EeVe Soul    600.0     140   120.00
# 360  Indian    Indian Super Chief Limited   1890.0     324    30.00
#
#         Prices  Ratings  Reviews
# 0     210784.0      3.7     2254
# 1     188868.0      3.5      738
# 2     205844.0      3.7     1995
# ...

# %% [markdown]
# ### Pairplot for co-relation of each columns

# %%
sns.pairplot(df,hue="Brand")

# %% [markdown]
# ### Highest price in over all brands

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="Brand",y="Prices",data=df,ci=None)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Using box plot showing the reviews in each rating

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x="Ratings",y="Reviews",data=df)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Most of the count of ratings

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Ratings",data=df)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Count of Mileage

# %%
plt.figure(figsize=(18,6))
sns.countplot(x="Mileage",data=df)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Count of Models in each Brand

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Brand",data=df)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Most reviewed Brand

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="Brand",y="Reviews",data=df,ci=None)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### High Prices Brand or Costliest Brand overall

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="Brand",y="Prices",data=df,ci=None)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Highest CC Bike Brand

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x="Brand",y="Bike CC",data=df)

plt.xticks(rotation=90)
plt.show()
